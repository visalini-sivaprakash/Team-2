# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your dataset
df=pd.read_csv(r"E:\Corizo Internship\Project 2  - Spotify Songs’ Genre Segmentation\spotify dataset.csv")
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
#top 5 rows
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
#bottom 5 rows
df.tail(5)
# Out:
#                      track_id                            track_name  \
# 32828  7bxnKAamR3snQ1VGLuVfC1  City Of Lights - Official Radio Edit
# 32829  5Aevni09Em4575077nkWHz   Closer - Sultan & Ned Shepard Remix
# 32830  7ImMqPP3Q1yfUHvsdn7wEo          Sweet Surrender - Radio Edit
# 32831  2m69mhnfQ1Oq6lGtXuYhgX        Only For You - Maor Levi Remix
# 32832  29zWqhca3zt5NsckZqDf6c                Typhoon - Original Mix
#
#          track_artist  track_popularity          track_album_id  \
# 32828    Lush & Simon                42  2azRoBBWEEEYhqV6sb7JrT
# 32829  Tegan and Sara                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830     Starkillers                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831          Mat Zo                15  1fGrOkHnHJcStl14zNx8Jy
# 32832    Julian Calor                27  0X3mUOm6MhxR7PzxG95rAo
#
#                    track_album_name track_album_release_date    playlist_name  \
# 32828    City Of Lights (Vocal Mix)               2014-04-28  ♥ EDM LOVE 2020
# ...

# %%
#Column names
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
#Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
# Description
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#Bar plot
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='playlist_genre')
plt.title('Playlist Genre Counts')
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='playlist_genre', data=df)
plt.title('Genre Distribution')
plt.show()

# %%
x=df["playlist_genre"]
y=df["duration_ms"]
plt.bar(x, y)
plt.xlabel("playlist_genre")
plt.ylabel("duration_ms")
plt.title("playlist_genre vs duration")
plt.show()

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Split data into train and test

# %%
x = df.drop('playlist_genre',axis = 1)#the features
y = df['playlist_genre']#the target

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)

# %%
xtrain
# Out:
#                      track_id  \
# 25915  3HoyAX58MUIBFCNmhMliHy
# 23332  3mmx1lskTHYD7YfbjKKRph
# 28018  7GVSFPQOFTvj9x96Vnq8Yu
# 31359  2sApUgcQQL2m0quuYgq0ec
# 30091  2GblQ918RbkOs4Yo1Rpkcj
# ...                       ...
# 24351  57ku0GRhHxZugoRpmMyKhn
# 10394  4MxYiw28F30NGOaTZ1ySqd
# 20594  1xRCGC0OUcavUYX6T4oDqH
# 29523  6vJFOgEWgVKb4ol7DHW0Tj
# 21500  2fhePAlCSsJplwkjqMYpVm
#
#                                               track_name     track_artist  \
# 25915                                  Love Calls - Main              Kem
# 23332                                          Feel jazz      Nidža Bleja
# 28018                            Muppa - Reece Low Remix          Contiez
# 31359                                               Sign            DEAMN
# 30091                                Rolling In The Deep            Adele
# ...                                                  ...              ...
# 24351                       Baby I'm Yours - Re-Recorded             Shai
# ...

# %%
len(xtrain)
# Out:
# 26266

# %%
ytrain
# Out:
# 25915      r&b
# 23332      r&b
# 28018      edm
# 31359      edm
# 30091      edm
#          ...
# 24351      r&b
# 10394      rap
# 20594    latin
# 29523      edm
# 21500      r&b
# Name: playlist_genre, Length: 26266, dtype: object

# %%
xtest
# Out:
#                      track_id                       track_name  \
# 25570  300DUx4tdtCdGEUXR032jA                     Palace/Curse
# 7946   1qu0VCx2idnR4O0hfxqdUR                     Dikke Tieten
# 13677  3zwmW1gM4E8FlHXV5nE16u                      Be Yourself
# 17029  2sTe3y5xjQvVb9tDTVaI35                          Rise Up
# 12157  26FJA5apYWeehOGnZdUPob  Body Language - Remastered 2011
# ...                       ...                              ...
# 7487   2ZMI0QNoqU9fQZFirR9WpK           When The Curtain Falls
# 23192  10l4fLEufBRs1OKFzl6map                           Poison
# 10055  3HOlhweyZyyD8QSTZjI63I                        Sommelier
# 12169  69Op4XR486hl5LSiBtPHmp                       Claroscuro
# 24448  0QKBG3v8kqpYEPkTrGg0Zt                        Graveyard
#
#           track_artist  track_popularity          track_album_id  \
# 25570     The Internet                62  69g3CtOVg98TPOwqmI2K7Q
# 7946             Kempi                25  5Qdamvl4vNpaQHYJhGeTDk
# ...

# %%
len(xtest)
# Out:
# 6567

# %%
xtrain.shape,xtest.shape
# Out:
# ((26266, 22), (6567, 22))

# %%
df.drop("track_name",axis=1)
# Out:
#                      track_id      track_artist  track_popularity  \
# 0      6f807x0ima9a1j3VPbc7VN        Ed Sheeran                66
# 1      0r7CVbZTWZgbTCYdfa2P31          Maroon 5                67
# 2      1z1Hg7Vb0AhHDiEmnDE79l      Zara Larsson                70
# 3      75FpbthrwQmzHlBJLuGdC7  The Chainsmokers                60
# 4      1e8PAfcKUYoKkxPhrHqw4x     Lewis Capaldi                69
# ...                       ...               ...               ...
# 32828  7bxnKAamR3snQ1VGLuVfC1      Lush & Simon                42
# 32829  5Aevni09Em4575077nkWHz    Tegan and Sara                20
# 32830  7ImMqPP3Q1yfUHvsdn7wEo       Starkillers                14
# 32831  2m69mhnfQ1Oq6lGtXuYhgX            Mat Zo                15
# 32832  29zWqhca3zt5NsckZqDf6c      Julian Calor                27
#
#                track_album_id  \
# 0      2oCs0DGTsRO98Gh5ZSl2Cx
# 1      63rPSO264uRjW1X5E6cWv6
# 2      1HoSmj2eLcsrR0vE9gThr4
# 3      1nqYsOef1yKKuGOVchbsk6
# ...

# %% [markdown]
# # Correlation Matrix

# %%
df=pd.read_csv(r"E:\Corizo Internship\Project 2  - Spotify Songs’ Genre Segmentation\spotify dataset.csv")
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
#Columns which are not required
columns_to_drop = ['track_id','track_name','track_artist','track_album_id','track_album_name','track_album_release_date','playlist_name','playlist_id','playlist_genre',
'playlist_subgenre','instrumentalness']
df1= df.drop(columns=columns_to_drop)

# %%
#correlation as heat map
cor=df1.corr()
sns.heatmap(cor, square = True)
# Out:
# <Axes: >

# %% [markdown]
# # Clustering - K Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
plt.scatter(df["track_popularity"],df["danceability"])

# %%
track_popularity	danceability	energy	key
# Out:
#   Cell In[75], line 1
#     track_popularity	danceability	energy	key
#                     	^
# SyntaxError: invalid syntax

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=5)
km.fit(df[["track_popularity","danceability"]])
# Out:
# E:\Anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %%
km.cluster_centers_
# Out:
# array([[59.78325786,  0.65550969],
#        [24.59329675,  0.64991925],
#        [42.76663464,  0.65466905],
#        [ 3.11650159,  0.64235572],
#        [76.94637104,  0.67298258]])

# %%
df["cluster_group"]=km.labels_
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
sns.scatterplot(x="track_popularity",y="danceability",hue="cluster_group",data=df)
# Out:
# <Axes: xlabel='track_popularity', ylabel='danceability'>

# %%
sns.scatterplot(x="playlist_genre",y="playlist_name",data=df,hue="cluster_group")
# Out:
# <Axes: xlabel='playlist_genre', ylabel='playlist_name'>
# E:\Anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128153 (\N{BLUE HEART}) missing from current font.
#   func(*args, **kwargs)
# E:\Anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 129321 (\N{GRINNING FACE WITH STAR EYES}) missing from current font.
#   func(*args, **kwargs)
# E:\Anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 129322 (\N{GRINNING FACE WITH ONE LARGE AND ONE SMALL EYE}) missing from current font.
#   func(*args, **kwargs)
# E:\Anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128138 (\N{PILL}) missing from current font.
#   func(*args, **kwargs)
# E:\Anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128057 (\N{HAMSTER FACE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.scatterplot(x="track_album_release_date",y="duration_ms",data=df,hue="cluster_group")
# Out:
# <Axes: xlabel='track_album_release_date', ylabel='duration_ms'>

# %%
cg2=df[df["cluster_group"]==2]
cg2
# Out:
#                      track_id  \
# 19     2v3DuCVBbopteJqdM7aKQK
# 51     5rxKInBVj0QE87KenyDiLf
# 53     5qCrT9lVmIGxqB8i6bb83P
# 60     6EDH26ppl7R8oV4tGilCkS
# 62     1nwoWaqzB30bD4IPqRNuex
# ...                       ...
# 32806  7fzNBlEWWRQIJrUZ1KaEwH
# 32815  6h9xi8i9zVOXk5FqGqcBNH
# 32825  2EpS5TgdngSISM63rhBsnK
# 32826  1EavLSmwRWtmkKEmlCfFzT
# 32828  7bxnKAamR3snQ1VGLuVfC1
#
#                                               track_name  track_artist  \
# 19                            Let It Be Me - Sondr Remix    Steve Aoki
# 51        Crash Into Me - Settle Down Steavis Aoki Remix    Steve Aoki
# 53                    Lovers + Strangers - GATTÜSO Remix       Starley
# 60                          Trampoline - Dave Audé Remix         SHAED
# 62                               With You - Dexter Remix       Kaskade
# ...                                                  ...           ...
# 32806  No One Knows Who We Are (Radio Edit) (feat. Li...       Kaskade
# ...

# %%
cg4=df[df["cluster_group"]==4]
cg4
# Out:
#                      track_id  \
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 4      1e8PAfcKUYoKkxPhrHqw4x
# 7      6b1RNvAcJjQH73eZO4BLAB
# 18     0GfS3y8Jd7SHWd9R51s7Fo
# 20     4QAUGy6k7c3IOAhgWz52r7
# ...                       ...
# 32487  0lks2Kt9veMOFEAPN0fsqN
# 32503  3gicyfiEVMGONgzygpWjNT
# 32520  6b1RNvAcJjQH73eZO4BLAB
# 32530  1ahVFh0ViDZr8LvkEVlq3B
# 32758  6PUIzlqotEmPuBfjbwYWOB
#
#                                               track_name   track_artist  \
# 2                        All the Time - Don Diablo Remix   Zara Larsson
# 4                Someone You Loved - Future Humans Remix  Lewis Capaldi
# 7               Post Malone (feat. RANI) - GATTÜSO Remix      Sam Feldt
# 18     Dancing With A Stranger (With Normani) - Cheat...      Sam Smith
# 20                  Heaven - David Guetta & MORTEN Remix         Avicii
# ...                                                  ...            ...
# 32487                                               Lily    Alan Walker
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ip = df.select_dtypes(include=['number', 'bool'])
op = df['playlist_genre']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(ip, op, train_size=0.8, random_state=42)

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
predictions = rfc.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(ytest, predictions)

# %%
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 56.16%
